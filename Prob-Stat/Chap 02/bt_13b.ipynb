# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
vtx = np.random.normal(size=10000)
vty = np.exp(vtx)

# %%
plt.hist(vty, 100)
# Out:
# (array([  2.96400000e+03,   2.56100000e+03,   1.46900000e+03,
#           9.41000000e+02,   5.51000000e+02,   3.85000000e+02,
#           2.68000000e+02,   1.94000000e+02,   1.44000000e+02,
#           1.05000000e+02,   8.30000000e+01,   6.00000000e+01,
#           4.20000000e+01,   4.30000000e+01,   3.20000000e+01,
#           2.40000000e+01,   1.60000000e+01,   1.80000000e+01,
#           1.60000000e+01,   1.30000000e+01,   6.00000000e+00,
#           1.00000000e+01,   5.00000000e+00,   5.00000000e+00,
#           5.00000000e+00,   8.00000000e+00,   2.00000000e+00,
#           4.00000000e+00,   3.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   2.00000000e+00,   2.00000000e+00,
#           1.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           2.00000000e+00,   0.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   2.00000000e+00,
# ...
